# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def prepare_shopee():
    driver = webdriver.Chrome(executable_path=r'C:\Users\User\Desktop\bootcamp 24\bootcamp 24 class 6\chromedriver.exe')
    driver.get('https://shopee.co.th/')
    thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
    thai_button.click()
    close_popup = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
    close_popup.click()
    return driver


def prepare_data(driver):
    search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')
    search_bar.click()
    search_bar.send_keys('เก้าอี้ ergonomic')
    search_bar.send_keys(Keys.ENTER)
    driver.execute_script('document.body.style.zoom="10%"')
    return driver

# %%
driver = prepare_shopee()
driver = prepare_data(driver)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1110562527.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\User\Desktop\bootcamp 24\bootcamp 24 class 6\chromedriver.exe')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1110562527.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1110562527.py:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %%
import pandas as pd
import bs4
import time

time.sleep(2)
html_string = driver.page_source

soup = bs4.BeautifulSoup(html_string)
all_listing = soup.find_all('div',{'data-sqe':'item'})

name_list = []
price_list = []
for listing in all_listing:

    name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
    price = listing.find('div',{'class':'hpDKMN'}).text

    name_list.append(name)
    price_list.append(price)


pd.DataFrame([name_list,price_list]).transpose()
# Out:
#                                                     0                1
# 0   เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699
# 1   NUBWO CH-011 เก้าอี้เกมมิ่ง Gaming Chair - (Bl...     ฿5,490฿4,490
# 2   SIGNO E-Sport GC-205 BLACKER Gaming Chair เก้า...     ฿5,490฿4,790
# 3   Neolution E-Sport Twilight Gaming RGB Chair (G...     ฿5,990฿4,490
# 4   [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOS...    ฿15,900฿7,900
# 5   YYM เก้าอี้พับเก้าอี้ปรับนอน เตียงพับ เก้าอี้พ...      ฿199 - ฿999
# 6   Hotmotor (ถูกที่สุด) เก้าอี้สำนักงาน ขาเหล็ก เ...  ฿1,045 - ฿1,699
# 7   Hotmotor (ถูกที่สุด) เก้าอี้ทำงาน เก้าอี้ พนัก...  ฿1,045 - ฿1,899
# 8   Razer Iskur X - Hello Kitty and Friends Editio...          ฿17,990
# 9   DECORSTUDIO เก้าอี้ปรับเอน Zero Gravity Chair ...  ฿1,290 - ฿1,850
# 10  🍊เก้าอี้สำนักงาน ปรับระดับได้ หลังตาข่าย สูง 1...       ฿2,999฿890
# 11     ONEX GAMING CHAIR (เก้าอี้เกมมิ่ง) GX3 (BLACK)           ฿6,370
# 12  [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 13  เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสู...    ฿999 - ฿1,599
# 14  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ฿3,990฿1,469
# 15  Anda Seat Iron Man Edition Marvel Collaboratio...          ฿15,900
# 16  MMY  เก้าอี้ 49*45*81cm เก้าอี้สไตล์ ขาไม้สีบี...      ฿289 - ฿549
# 17  เก้าอี้ รุ่น Dota เก้าอี้เกมส์ เก้าอี้เกมมิ่ง ...     ฿7,960฿1,990
# 18  เก้าอี้สแตนเลส เกรด201 เก้าอี้กลมขาคู่ เก้าอี้...      ฿157 - ฿195
# 19  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...    ฿959 - ฿1,390
# 20  Neolution E-sport Gaming Chair รุ่น G808 (G7_1...     ฿1,990฿1,790
# 21  SIGNO E-Sport Gaming Chair BAROCK รุ่น GC-202 ...     ฿4,390฿4,190
# 22  LD เก้าอี้สำนักงาน เก้าอี้ เบาะกว้าง ปรับสูง-ต...     ฿2,299฿1,249
# 23  ONEX GE300 เก้าอี้เกมมิ่ง รับน้ำหนักสูงสุด 150...     ฿5,990฿5,690
# 24  FANTECH GC283 ALPHA GAMING CHAIR เก้าอี้เกมมิ่...           ฿6,990
# 25  🔥โปรแรง 🔥เปลญวน แบบแขวน เปลเก้าอี้นั่ง ทรงกลม ...       ฿1,594฿829
# 26  [HOT DEAL] เก้าอี้ ADDE โครงเหล็ก เบาะโพลี สาม...      ฿379 - ฿399
# 27  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...             ฿469
# 28  เก้าอี้สำนักงาน เก้าอี้พักผ่อน เก้าอี้ผู้บริหา...    ฿995 - ฿1,595
# 29   HomeHuk เก้าอี้สำนักงาน เบาะหนัง รุ่น Worq Of...     ฿2,890฿1,489
# 30  Miren เก้าอี้สำนักงาน ล้อเลื่อน พนักพิงหลังสูง...       ฿1,600฿999
# 31  XTAURI เก้าอี้นั่งเล่นเกมส์คอมพิวเตอร์ เก้าอี้...     ฿3,999฿1,559
# 32  [ส่งฟรี] HAKONE เก้าอี้ทำงาน เบาะหนัง ผสมผ้า L...     ฿5,990฿3,190
# 33  เก้าอี้เกมมิ่ง เก้าอี้ทำงาน เก้าอี้สุขภาพ  พนั...     ฿2,835฿1,889
# 34  เก้าอี้คอมพิวเตอร์ เก้าอี้สำนักงาน เก้าอี้ปรับ...  ฿1,939 - ฿2,299
# 35                IKEA เก้าอี้ทำงาน ปรับได้ renberget           ฿2,222
# 36  WJ เก้าอี้สำนักงาน เก้าอี้เล่นคอมพิวเตอร์ ที่ว...  ฿1,159 - ฿1,790
# 37  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...             ฿469
# 38   HomeHuk เก้าอี้สำนักงาน รุ่น Worq Office Chai...     ฿3,990฿2,099
# 39  เก้าอี้ รุ่น ROBOT ปรับสูง-ต่ำ ปรับแขนขึ้น-ลง ...      ฿859 - ฿899
# 40   HomeHuk เก้าอี้สำนักงาน รุ่น Worq Mesh High B...     ฿2,990฿1,759
# 41  FANTECH GC181A ALPHA GAMING CHAIR เก้าอี้เกมมิ...           ฿4,130
# 42  SIGNO E-Sport Gaming Chair BRANCO รุ่น GC-207 ...     ฿5,990฿5,890
# 43  เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gaming Chair ปรั...  ฿1,234 - ฿3,990
# 44  🔥ถูกที่สุด🔥เก้าอี้พักผ่อน เก้าอี้พับ ปรับเอนนั...    ฿985 - ฿1,985
# 45  HomeHuk เก้าอี้กินข้าว พนักพิงโค้ง ฐานโครงเหล็...       ฿1,250฿489
# 46    [ทักแชทรับโค้ด] ThunderX3 Gaming Chair รุ่น TC3     ฿6,490฿5,390
# 47   Nubwo เก้าอี้เล่นเกม BLACK NBCH-019 Gaming Chair           ฿4,190
# 48  WOWLife เก้าอี้พักผ่อน ปรับเอนนอนได้ นุ่มสบายม...         ฿890฿520
# 49  MSI GAMING CHAIR (เก้าอี้เกมมิ่ง) MAG CH130 X ...          ฿10,400
# 50  เก้าอี้พักผ่อน ปรับนอนได้ นุ่มสบายมีระบาย เก้า...  ฿1,499 - ฿5,720
# 51  U-RO DECOR เก้าอี้สำนักงาน รุ่น HIRO พนักพิงสู...     ฿2,990฿1,490
# 52  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ฿4,590฿1,999
# 53  🔥UPick1 เก้าอี้สำนักงาน เก้าอี้เล่นคอม 46x55x1...     ฿1,699฿1,189
# 54  เก้าอี้เกมส์  Gaming Chair  รุ่น E-02NEW ( Red...     ฿2,590฿1,799
# 55  YiFeng เก้าอี้ สไตล์โมเดิร์น  เก้าอี้พลาสติก ข...      ฿173 - ฿513
# 56  [Best Seller] Bewell Ergonomic chair เก้าอี้ทำ...   ฿29,900฿19,900
# 57  [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 58  🔥พร้อมส่ง🔥เก้าอี้แค้มปิ้ง เก้าอี้พับ เก้าอี้แค...  ฿1,099 - ฿1,150
# 59  NUBWO CH-010 เก้าอี้เกมมิ่ง Gaming Chair (รับป...     ฿4,990฿2,690

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def prepare_shopee(chromedriver_path):
    driver = webdriver.Chrome(executable_path=chromedriver_path)
    driver.get('https://shopee.co.th/')
    thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
    thai_button.click()
    close_popup = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
    close_popup.click()
    return driver

def prepare_data(driver,keyword):
    search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')
    search_bar.click()
    search_bar.send_keys(keyword)
    search_bar.send_keys(Keys.ENTER)
    driver.execute_script('document.body.style.zoom="10%"')
    return driver

# %%
import pyautogui

# %%
keyword = pyautogui.prompt(text='ใส่ keyword ที่ต้องการค้นหา',title='shopee_scraper')
keyword
# Out:
# 'chair'

# %%
chromedriver_path = pyautogui.prompt(text='ใส่ที่อยู่ของไฟล์ chromedriver.exe',title='shopee_scraper')
chromedriver_path
# Out:
# 'C:\\Users\\User\\Desktop\\bootcamp 24\\bootcamp 24 class 6\\chromedriver.exe'

# %%
driver = prepare_shopee(chromedriver_path)
driver = prepare_data(driver,keyword)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1243957887.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path)
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1243957887.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/1243957887.py:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %% [markdown]
# ### checkpont 4

# %%
import pandas as pd
import bs4
import time

time.sleep(2)
html_string = driver.page_source

soup = bs4.BeautifulSoup(html_string)
all_listing = soup.find_all('div',{'data-sqe':'item'})

name_list = []
price_list = []
for listing in all_listing:

    name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
    price = listing.find('div',{'class':'hpDKMN'}).text

    name_list.append(name)
    price_list.append(price)


pd.DataFrame([name_list,price_list]).transpose()
# Out:
#                                                     0                1
# 0   เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699
# 1   SIGNO E-Sport GC-205 BLACKER Gaming Chair เก้า...     ฿5,490฿4,790
# 2   NUBWO CH-011 เก้าอี้เกมมิ่ง Gaming Chair - (Bl...     ฿5,490฿4,490
# 3   [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOS...    ฿15,900฿7,900
# 4   YiFeng เก้าอี้ สไตล์โมเดิร์น  เก้าอี้พลาสติก ข...      ฿173 - ฿513
# 5   Hotmotor (ถูกที่สุด) เก้าอี้สำนักงาน ขาเหล็ก เ...  ฿1,045 - ฿1,699
# 6   YYM เก้าอี้พับเก้าอี้ปรับนอน เตียงพับ เก้าอี้พ...      ฿199 - ฿999
# 7   Hotmotor (ถูกที่สุด) เก้าอี้ทำงาน เก้าอี้ พนัก...  ฿1,045 - ฿1,899
# 8   เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสู...    ฿999 - ฿1,599
# 9   [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 10  เก้าอี้สแตนเลส เกรด201 เก้าอี้กลมขาคู่ เก้าอี้...      ฿157 - ฿195
# 11  MMY  เก้าอี้ 49*45*81cm เก้าอี้สไตล์ ขาไม้สีบี...      ฿289 - ฿549
# 12  Neolution E-sport Gaming Chair รุ่น G808 (G7_1...     ฿1,990฿1,790
# 13  เก้าอี้สำนักงาน เก้าอี้พักผ่อน เก้าอี้ผู้บริหา...    ฿995 - ฿1,595
# 14  [HOT DEAL] เก้าอี้ ADDE โครงเหล็ก เบาะโพลี สาม...      ฿379 - ฿399
# 15  เก้าอี้ รุ่น ROBOT ปรับสูง-ต่ำ ปรับแขนขึ้น-ลง ...      ฿859 - ฿899
# 16  เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gaming Chair ปรั...  ฿1,234 - ฿3,990
# 17  🔥UPick1 เก้าอี้สำนักงาน เก้าอี้เล่นคอม 46x55x1...     ฿1,699฿1,189
# 18  WOWLife เก้าอี้พักผ่อน ปรับเอนนอนได้ นุ่มสบายม...         ฿890฿520
# 19  (เก้าอี้เกมมิ่ง) GAMING CHAIR SPEED SPGX1 SHAD...     ฿5,990฿1,990
# 20  เก้าอี้พักผ่อน เตียงพับ เก้าอี้พับ ปรับเอนนอนไ...      ฿689 - ฿949
# 21  โฮมออฟฟิศ Office Chair เก้าอี้สำนักงาน เก้าอี้...       ฿1,290฿479
# 22  KUMALL เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน มี...       ฿1,599฿539
# 23         Tengu เก้าอี้เล่นเกม Muramasa Gaming Chair           ฿2,490
# 24  เก้าอี้ทรงรถแข่ง มีหมอนรองหลังและคอ เก้าอี้เล่...  ฿1,259 - ฿1,799
# 25  BIGWOODS เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่ง...    ฿799 - ฿1,479
# 26  [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภา...     ฿6,990฿4,590
# 27  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...    ฿959 - ฿1,390
# 28  Nubwo Gaming Chair NBCH-024 แถมฟรี!!! ลำโพงรุ่...     ฿4,390฿2,990
# 29      Furinbox เก้าอี้สำนักงาน รุ่น COOPER - (สีดำ)     ฿3,990฿1,590
# 30  (เก้าอี้เกมมิ่ง) THUNDER X3 DC3 GAMING  CHAIR ...     ฿6,390฿6,190
# 31  SIGNO E-Sport Gaming Chair BLACKER รุ่น GC-205...           ฿4,790
# 32  เก้าอี้ เก้าอี้สำนักงาน Office Chair เก้าอี้ทำ...         ฿799฿465
# 33  kalevell เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร...    ฿999 - ฿1,588
# 34  เก้าอี้ทำงาน เก้าอี้สำนักงาน เก้าอี้ เก้าอี้ออ...    ฿995 - ฿1,245
# 35  เก้าอี้ใส่เม็ดโฟมแล้ว CARLINO: พร้อมใช้งาน  ขน...       ฿1,000฿599
# 36  Anda Seat เก้าอี้เล่นเกม รุ่น Kaiser Series Pr...          ฿15,900
# 37  ใหม่ล่าสุด!! ส่งเร็ว🚚!! ถูกสุด🔥เก้าอี้ออฟฟิศ เ...      ฿497 - ฿849
# 38  [🏃ราคาพิเศษ สู้โควิด😍] เก้าอี้พับ เก้าอี้สนาม ...       ฿99 - ฿189
# 39  GIOCOSO เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่งทำง...         ฿990฿485
# 40  🔥ถูกที่สุด🔥วันเดียวเท่านั้น! เก้าอี้สำนักงาน ข...      ฿199 - ฿585
# 41  เก้าอี้ เก้าอี้ออฟฟิศ เก้าอี้ทำงาน  เก้าอี้สำน...      ฿459 - ฿489
# 42     THUNDER X3 DC3 GAMING  CHAIR BLACK By Speedcom           ฿6,190
# 43  Baanmainicha เก้าอี้ปรับนอน เก้าอี้พักผ่อน เก้...           ฿1,980
# 44  เก้าอี้พลาสติกมีพนักพิง ราคาถูก เก้าอี้นั่งทาน...         ฿250฿109
# 45  เก้าอี้ รุ่น B (Black) Office Chair โฮมออฟฟิศ ...         ฿990฿499
# 46  [คืน 500c. ทักแชทรับโค้ด] ONEX-GX3 Gaming Chai...  ฿5,990 - ฿6,290
# 47    Tengu เก้าอี้เล่นเกม รุ่น Kusanagi Gaming Chair  ฿2,020 - ฿2,590
# 48  MIREN เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร นั...    ฿999 - ฿1,598
# 49  MIREN เก้าอี้ เก้าอี้สำนักงาน เก้าอี้บาร์ ใช้ใ...         ฿700฿454
# 50  MABUY เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่งสบา...    ฿899 - ฿1,589
# 51  พร้อมส่งจ้า👽เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gami...  ฿1,499 - ฿3,299
# 52  เก้าอี้ขาเหล็กคู่ 18 24 30 นิ้ว เก้าอี้บาร์ เก...      ฿295 - ฿395
# 53  มาแล้ว เก้าอี้มาเล เก้าอี้นั่งปรับนอนได้ เก้าอ...             ฿550
# 54  🔥ถูกที่สุด🔥เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่ง...    ฿320 - ฿1,599
# 55  Neolution E-Sport Twilight Gaming RGB Chair (G...     ฿5,990฿4,490
# 56  [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 57  NUBWO CH-010 เก้าอี้เกมมิ่ง Gaming Chair (รับป...     ฿4,990฿2,690
# 58  🔥พร้อมส่ง🔥เก้าอี้แค้มปิ้ง เก้าอี้พับ เก้าอี้แค...  ฿1,099 - ฿1,150
# 59  [Best Seller] Bewell Ergonomic chair เก้าอี้ทำ...   ฿29,900฿19,900

# %% [markdown]
# ### checkpoint 5

# %%
import pandas as pd
import bs4
import time

def get_shopee_df(driver):
    time.sleep(2)
    html_string = driver.page_source
    soup = bs4.BeautifulSoup(html_string)
    all_listing = soup.find_all('div',{'data-sqe':'item'})

    name_list = []
    price_list = []
    for listing in all_listing:

        name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
        price = listing.find('div',{'class':'hpDKMN'}).text
        name_list.append(name)
        price_list.append(price)

    shopee_df = pd.DataFrame([name_list,price_list]).transpose()
    return shopee_df

# %%
shopee_df = get_shopee_df(driver)
shopee_df
# Out:
#                                                     0                1
# 0   [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 1   เก้าอี้เพื่อสุขภาพ รุ่น BIONIC  เก้าอี้ เก้าอี...     ฿9,990฿4,990
# 2   [Best Seller] Bewell Ergonomic chair เก้าอี้ทำ...   ฿29,900฿19,900
# 3   [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOS...    ฿15,900฿7,900
# 4   [ส่งฟรี รับประกัน3ปี ผ่อน0%] ERGONOMATE เก้าอี...    ฿11,900฿7,190
# 5   เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสู...    ฿999 - ฿1,599
# 6   (ที่วางแขนปรับได้) เก้าอี้สำนักงาน ขาเหล็ก พนั...      ฿799 - ฿888
# 7   [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700
# 8   เก้าอี้เพื่อสุขภาพ รุ่น BIONIC  เก้าอี้ เก้าอี...     ฿9,990฿4,990
# 9   เก้าอี้ทำงาน Office Chair เก้าอี้สำนักงาน เก้า...      ฿599 - ฿729
# 10  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ฿3,990฿1,469
# 11  Bewell Ergonomic chair เก้าอี้ทำงานเพื่อสุขภาพ...   ฿29,900฿19,800
# 12  Bewell Ergonomic chair เก้าอี้ทำงานเพื่อสุขภาพ...   ฿25,900฿15,900
# 13  [ส่งฟรี + ราคาพิเศษ🔥] ทักแชทรับโค้ดลดเพิ่ม เช็...   ฿77,400฿58,200
# 14  Woodpanda (พรีออเดอร์) เก้าอี้สำนักงาน เก้าอี้...           ฿1,199
# 15  Elife เก้าอี้ทำงาน Ergonomic chair เก้าอี้สำนั...     ฿6,990฿3,190
# 16  LVNI office chair เก้าอี้ทำงาน เก้าอี้เพื่อสุข...     ฿3,990฿2,699
# 17  Betensh Ergonomic Chair (พร้อมจัดส่ง) เก้าอี้ส...  ฿1,759 - ฿1,859
# 18  【ส่วนลด 50%】♦☎✥Ergonomic chair  เก้าอี้หนังสไต...  ฿1,323 - ฿1,404
# 19  [พร้อมส่ง ราคาสุดพิเศษ] Ergonomic Chair เยอรมั...    ฿12,000฿5,699
# 20  LVNI RISE Ergonomic chair เก้าอี้ทำงานเพื่อสุข...   ฿19,990฿16,900
# 21  MIREN เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร นั...    ฿999 - ฿1,598
# 22  Autofull gaming chair (G7_135) รุ่นAF805 เบาะห...     ฿8,590฿7,990
# 23      เก้าอี้สุขภาพ FULI X8 ErgoChair - White สีขาว     ฿4,999฿3,999
# 24  【ส่วนลด 50%】✹๑Ergonomic chair  เก้าอี้หนังสไตล...  ฿1,309 - ฿1,387
# 25  [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภา...     ฿6,990฿4,590
# 26  Fennix Ergonomic Chair HC-6H01 เก้าอี้ทำงานเพื...     ฿3,990฿2,790
# 27  [คืน 334c. ทักแชทรับโค้ด] Fennix Ergonomic  Ch...  ฿2,790 - ฿2,990
# 28  Fennix Ergonomic Chair HC-6H01 เก้าอี้ทำงานเพื...           ฿2,790
# 29  Autofull gaming chair (G7_140) รุ่นAF050 เบาะก...     ฿9,900฿8,999
# 30  เก้าอี้ทำงาน มี 2 รุ่นให้เลือก Ergonomic chair...     ฿8,960฿2,999
# 31  [ทักแชทรับโค้ด] Nubwo Gaming Chair รุ่น Empero...  ฿3,590 - ฿4,589
# 32  NEW Cartoon Pikachu Wcg Gaming Chair Anchor Ar...  ฿2,999 - ฿3,499
# 33  เก้าอี้เพื่อสุขภาพ นั่งสบาย ThunderX3 YAMA1 ER...     ฿5,190฿5,139
# 34  เก้าอี้เพื่อสุขภาพเด็ก เก้าอี้ปรับระดับได้ สำห...     ฿5,600฿2,800
# 35  LVNI Ergonomic Chair เก้าอี้ตามหลักสรีรศาสตร์ ...  ฿4,590 - ฿5,090
# 36  [พร้อมจัดส่ง] Modena ที่พักเท้าเพื่อสุขภาพ | E...       ฿1,590฿990
# 37  Autofull gaming chair (G7_138) รุ่นAF075 เบาะห...    ฿10,500฿8,500
# 38  (ชิ้นใหญ่ สั่งครั้งละ1 ตัว)Ergonomic chair  เก...             ฿595
# 39       เก้าอี้ Ergonomic ยี่ห้อ Dreamdesk Mesh-gray           ฿8,500
# 40  Autofull gaming chair (G7_137) รุ่นAF077 เบาะห...    ฿10,900฿9,500
# 41  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ฿4,950฿1,990
# 42  Xiaomi youpin YM Ergonomic Office Chair เก้าอี...  ฿7,599 - ฿8,499
# 43  Autofull Gaming Chair + Ergonomic เก้าอี้เกมมิ...          ฿15,900
# 44  Autofull gaming chair (G7_136) รุ่นAF802 เบาะห...     ฿9,900฿8,990
# 45  Siam Steel เก้าอี้สำนักงาน รุ่นViper High Back...     ฿7,900฿5,925
# 46  เก้าอี้CHAIR THUNDER X3 YAMA1 ERGONOMIC (Black...           ฿4,990
# 47  เก้าอี้ทำงาน เก้าอี้สำนักงาน นุ่มสบาย เก้าอี้o...           ฿1,699
# 48  💥💥ส่งฟรีทั่วไทย💥💥เก้าอี้ Ergonomic design รองร...  ฿1,890 - ฿1,990
# 49  Fennix Ergonomic Chair HC-6H01 เก้าอี้ทำงานเพื...     ฿3,990฿2,790
# 50  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ฿4,590฿1,999
# 51  【ส่วนลด 50%】❡♟Ergonomic chair  เก้าอี้หนังสไตล...  ฿1,322 - ฿1,400
# 52  ห้องนั่งเล่นโซฟา Nordic กำมะหยี่เก้าอี้ Ergono...           ฿1,300
# 53  Siam Steel เก้าอี้สำนักงาน รุ่นViper High Back...     ฿7,900฿5,990
# 54  Xiaomi Yuemi YM Ergonomic Office Chair เก้าอี้...  ฿7,599 - ฿8,499
# 55  เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699
# 56  Xiaomi youpin YM Ergonomic Office Chair เก้าอี...  ฿7,599 - ฿8,499
# 57  [ส่งฟรี คืน299c. ทักแชท] Fennix Ergonomic  Cha...     ฿3,990฿2,790
# 58  [ส่งฟรี ผ่อน0%] ERGONOMATE เก้าอี้สำนักงาน เก้...    ฿15,900฿9,890
# 59  เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699

# %% [markdown]
# ### checkpoint 6

# %%
import pandas as pd
import bs4
import time

def get_shopee_df(driver):
    time.sleep(2)
    html_string = driver.page_source
    soup = bs4.BeautifulSoup(html_string)
    all_listing = soup.find_all('div',{'data-sqe':'item'})

    name_list = []
    price_list = []
    sales_list = []
    for listing in all_listing:

        name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
        price = listing.find('div',{'class':'hpDKMN'}).text
        sales = listing.find('div',{'class':'r6HknA'}).text
        
        name_list.append(name)
        price_list.append(price)

    shopee_df = pd.DataFrame([name_list,price_list,sales_list]).transpose()
    return shopee_df

# %%
shopee_df = get_shopee_df(driver)
shopee_df
# Out:
#                                                     0                1     2
# 0   เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699  None
# 1   SIGNO E-Sport GC-205 BLACKER Gaming Chair เก้า...     ฿5,490฿4,790  None
# 2   NUBWO CH-011 เก้าอี้เกมมิ่ง Gaming Chair - (Bl...     ฿5,490฿4,490  None
# 3   [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOS...    ฿15,900฿7,900  None
# 4   YiFeng เก้าอี้ สไตล์โมเดิร์น  เก้าอี้พลาสติก ข...      ฿173 - ฿513  None
# 5   Hotmotor (ถูกที่สุด) เก้าอี้สำนักงาน ขาเหล็ก เ...  ฿1,045 - ฿1,699  None
# 6   YYM เก้าอี้พับเก้าอี้ปรับนอน เตียงพับ เก้าอี้พ...      ฿199 - ฿999  None
# 7   Hotmotor (ถูกที่สุด) เก้าอี้ทำงาน เก้าอี้ พนัก...  ฿1,045 - ฿1,899  None
# 8   เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสู...    ฿999 - ฿1,599  None
# 9   [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700  None
# 10  เก้าอี้สแตนเลส เกรด201 เก้าอี้กลมขาคู่ เก้าอี้...      ฿157 - ฿195  None
# 11  MMY  เก้าอี้ 49*45*81cm เก้าอี้สไตล์ ขาไม้สีบี...      ฿289 - ฿549  None
# 12  Neolution E-sport Gaming Chair รุ่น G808 (G7_1...     ฿1,990฿1,790  None
# 13  เก้าอี้สำนักงาน เก้าอี้พักผ่อน เก้าอี้ผู้บริหา...    ฿995 - ฿1,595  None
# 14  [HOT DEAL] เก้าอี้ ADDE โครงเหล็ก เบาะโพลี สาม...      ฿379 - ฿399  None
# 15  เก้าอี้ รุ่น ROBOT ปรับสูง-ต่ำ ปรับแขนขึ้น-ลง ...      ฿859 - ฿899  None
# 16  เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gaming Chair ปรั...  ฿1,234 - ฿3,990  None
# 17  🔥UPick1 เก้าอี้สำนักงาน เก้าอี้เล่นคอม 46x55x1...     ฿1,699฿1,189  None
# 18  WOWLife เก้าอี้พักผ่อน ปรับเอนนอนได้ นุ่มสบายม...         ฿890฿520  None
# 19  (เก้าอี้เกมมิ่ง) GAMING CHAIR SPEED SPGX1 SHAD...     ฿5,990฿1,990  None
# 20  เก้าอี้พักผ่อน เตียงพับ เก้าอี้พับ ปรับเอนนอนไ...      ฿689 - ฿949  None
# 21  โฮมออฟฟิศ Office Chair เก้าอี้สำนักงาน เก้าอี้...       ฿1,290฿479  None
# 22  KUMALL เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน มี...       ฿1,599฿539  None
# 23         Tengu เก้าอี้เล่นเกม Muramasa Gaming Chair           ฿2,490  None
# 24  เก้าอี้ทรงรถแข่ง มีหมอนรองหลังและคอ เก้าอี้เล่...  ฿1,259 - ฿1,799  None
# 25  BIGWOODS เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่ง...    ฿799 - ฿1,479  None
# 26  [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภา...     ฿6,990฿4,590  None
# 27  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...    ฿959 - ฿1,390  None
# 28  Nubwo Gaming Chair NBCH-024 แถมฟรี!!! ลำโพงรุ่...     ฿4,390฿2,990  None
# 29      Furinbox เก้าอี้สำนักงาน รุ่น COOPER - (สีดำ)     ฿3,990฿1,590  None
# 30  (เก้าอี้เกมมิ่ง) THUNDER X3 DC3 GAMING  CHAIR ...     ฿6,390฿6,190  None
# 31  SIGNO E-Sport Gaming Chair BLACKER รุ่น GC-205...           ฿4,790  None
# 32  เก้าอี้ เก้าอี้สำนักงาน Office Chair เก้าอี้ทำ...         ฿799฿465  None
# 33  kalevell เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร...    ฿999 - ฿1,588  None
# 34  เก้าอี้ทำงาน เก้าอี้สำนักงาน เก้าอี้ เก้าอี้ออ...    ฿995 - ฿1,245  None
# 35  เก้าอี้ใส่เม็ดโฟมแล้ว CARLINO: พร้อมใช้งาน  ขน...       ฿1,000฿599  None
# 36  Anda Seat เก้าอี้เล่นเกม รุ่น Kaiser Series Pr...          ฿15,900  None
# 37  ใหม่ล่าสุด!! ส่งเร็ว🚚!! ถูกสุด🔥เก้าอี้ออฟฟิศ เ...      ฿497 - ฿849  None
# 38  [🏃ราคาพิเศษ สู้โควิด😍] เก้าอี้พับ เก้าอี้สนาม ...       ฿99 - ฿189  None
# 39  GIOCOSO เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่งทำง...         ฿990฿485  None
# 40  🔥ถูกที่สุด🔥วันเดียวเท่านั้น! เก้าอี้สำนักงาน ข...      ฿199 - ฿585  None
# 41  เก้าอี้ เก้าอี้ออฟฟิศ เก้าอี้ทำงาน  เก้าอี้สำน...      ฿459 - ฿489  None
# 42     THUNDER X3 DC3 GAMING  CHAIR BLACK By Speedcom           ฿6,190  None
# 43  Baanmainicha เก้าอี้ปรับนอน เก้าอี้พักผ่อน เก้...           ฿1,980  None
# 44  เก้าอี้พลาสติกมีพนักพิง ราคาถูก เก้าอี้นั่งทาน...         ฿250฿109  None
# 45  เก้าอี้ รุ่น B (Black) Office Chair โฮมออฟฟิศ ...         ฿990฿499  None
# 46  [คืน 500c. ทักแชทรับโค้ด] ONEX-GX3 Gaming Chai...  ฿5,990 - ฿6,290  None
# 47    Tengu เก้าอี้เล่นเกม รุ่น Kusanagi Gaming Chair  ฿2,020 - ฿2,590  None
# 48  MIREN เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร นั...    ฿999 - ฿1,598  None
# 49  MIREN เก้าอี้ เก้าอี้สำนักงาน เก้าอี้บาร์ ใช้ใ...         ฿700฿454  None
# 50  MABUY เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่งสบา...    ฿899 - ฿1,589  None
# 51  พร้อมส่งจ้า👽เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gami...  ฿1,499 - ฿3,299  None
# 52  เก้าอี้ขาเหล็กคู่ 18 24 30 นิ้ว เก้าอี้บาร์ เก...      ฿295 - ฿395  None
# 53  มาแล้ว เก้าอี้มาเล เก้าอี้นั่งปรับนอนได้ เก้าอ...             ฿550  None
# 54  🔥ถูกที่สุด🔥เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่ง...    ฿320 - ฿1,599  None
# 55  Neolution E-Sport Twilight Gaming RGB Chair (G...     ฿5,990฿4,490  None
# 56  [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700  None
# 57  NUBWO CH-010 เก้าอี้เกมมิ่ง Gaming Chair (รับป...     ฿4,990฿2,690  None
# 58  🔥พร้อมส่ง🔥เก้าอี้แค้มปิ้ง เก้าอี้พับ เก้าอี้แค...  ฿1,099 - ฿1,150  None
# 59  [Best Seller] Bewell Ergonomic chair เก้าอี้ทำ...   ฿29,900฿19,900  None

# %% [markdown]
# ### checkpoint 7 ตั้งชื่อ column

# %%
shopee_df.columns = ['product','price','sales']
shopee_df
# Out:
#                                               product            price sales
# 0   เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ฿6,698฿4,699  None
# 1   SIGNO E-Sport GC-205 BLACKER Gaming Chair เก้า...     ฿5,490฿4,790  None
# 2   NUBWO CH-011 เก้าอี้เกมมิ่ง Gaming Chair - (Bl...     ฿5,490฿4,490  None
# 3   [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOS...    ฿15,900฿7,900  None
# 4   YiFeng เก้าอี้ สไตล์โมเดิร์น  เก้าอี้พลาสติก ข...      ฿173 - ฿513  None
# 5   Hotmotor (ถูกที่สุด) เก้าอี้สำนักงาน ขาเหล็ก เ...  ฿1,045 - ฿1,699  None
# 6   YYM เก้าอี้พับเก้าอี้ปรับนอน เตียงพับ เก้าอี้พ...      ฿199 - ฿999  None
# 7   Hotmotor (ถูกที่สุด) เก้าอี้ทำงาน เก้าอี้ พนัก...  ฿1,045 - ฿1,899  None
# 8   เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสู...    ฿999 - ฿1,599  None
# 9   [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700  None
# 10  เก้าอี้สแตนเลส เกรด201 เก้าอี้กลมขาคู่ เก้าอี้...      ฿157 - ฿195  None
# 11  MMY  เก้าอี้ 49*45*81cm เก้าอี้สไตล์ ขาไม้สีบี...      ฿289 - ฿549  None
# 12  Neolution E-sport Gaming Chair รุ่น G808 (G7_1...     ฿1,990฿1,790  None
# 13  เก้าอี้สำนักงาน เก้าอี้พักผ่อน เก้าอี้ผู้บริหา...    ฿995 - ฿1,595  None
# 14  [HOT DEAL] เก้าอี้ ADDE โครงเหล็ก เบาะโพลี สาม...      ฿379 - ฿399  None
# 15  เก้าอี้ รุ่น ROBOT ปรับสูง-ต่ำ ปรับแขนขึ้น-ลง ...      ฿859 - ฿899  None
# 16  เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gaming Chair ปรั...  ฿1,234 - ฿3,990  None
# 17  🔥UPick1 เก้าอี้สำนักงาน เก้าอี้เล่นคอม 46x55x1...     ฿1,699฿1,189  None
# 18  WOWLife เก้าอี้พักผ่อน ปรับเอนนอนได้ นุ่มสบายม...         ฿890฿520  None
# 19  (เก้าอี้เกมมิ่ง) GAMING CHAIR SPEED SPGX1 SHAD...     ฿5,990฿1,990  None
# 20  เก้าอี้พักผ่อน เตียงพับ เก้าอี้พับ ปรับเอนนอนไ...      ฿689 - ฿949  None
# 21  โฮมออฟฟิศ Office Chair เก้าอี้สำนักงาน เก้าอี้...       ฿1,290฿479  None
# 22  KUMALL เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน มี...       ฿1,599฿539  None
# 23         Tengu เก้าอี้เล่นเกม Muramasa Gaming Chair           ฿2,490  None
# 24  เก้าอี้ทรงรถแข่ง มีหมอนรองหลังและคอ เก้าอี้เล่...  ฿1,259 - ฿1,799  None
# 25  BIGWOODS เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่ง...    ฿799 - ฿1,479  None
# 26  [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภา...     ฿6,990฿4,590  None
# 27  เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ ...    ฿959 - ฿1,390  None
# 28  Nubwo Gaming Chair NBCH-024 แถมฟรี!!! ลำโพงรุ่...     ฿4,390฿2,990  None
# 29      Furinbox เก้าอี้สำนักงาน รุ่น COOPER - (สีดำ)     ฿3,990฿1,590  None
# 30  (เก้าอี้เกมมิ่ง) THUNDER X3 DC3 GAMING  CHAIR ...     ฿6,390฿6,190  None
# 31  SIGNO E-Sport Gaming Chair BLACKER รุ่น GC-205...           ฿4,790  None
# 32  เก้าอี้ เก้าอี้สำนักงาน Office Chair เก้าอี้ทำ...         ฿799฿465  None
# 33  kalevell เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร...    ฿999 - ฿1,588  None
# 34  เก้าอี้ทำงาน เก้าอี้สำนักงาน เก้าอี้ เก้าอี้ออ...    ฿995 - ฿1,245  None
# 35  เก้าอี้ใส่เม็ดโฟมแล้ว CARLINO: พร้อมใช้งาน  ขน...       ฿1,000฿599  None
# 36  Anda Seat เก้าอี้เล่นเกม รุ่น Kaiser Series Pr...          ฿15,900  None
# 37  ใหม่ล่าสุด!! ส่งเร็ว🚚!! ถูกสุด🔥เก้าอี้ออฟฟิศ เ...      ฿497 - ฿849  None
# 38  [🏃ราคาพิเศษ สู้โควิด😍] เก้าอี้พับ เก้าอี้สนาม ...       ฿99 - ฿189  None
# 39  GIOCOSO เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่งทำง...         ฿990฿485  None
# 40  🔥ถูกที่สุด🔥วันเดียวเท่านั้น! เก้าอี้สำนักงาน ข...      ฿199 - ฿585  None
# 41  เก้าอี้ เก้าอี้ออฟฟิศ เก้าอี้ทำงาน  เก้าอี้สำน...      ฿459 - ฿489  None
# 42     THUNDER X3 DC3 GAMING  CHAIR BLACK By Speedcom           ฿6,190  None
# 43  Baanmainicha เก้าอี้ปรับนอน เก้าอี้พักผ่อน เก้...           ฿1,980  None
# 44  เก้าอี้พลาสติกมีพนักพิง ราคาถูก เก้าอี้นั่งทาน...         ฿250฿109  None
# 45  เก้าอี้ รุ่น B (Black) Office Chair โฮมออฟฟิศ ...         ฿990฿499  None
# 46  [คืน 500c. ทักแชทรับโค้ด] ONEX-GX3 Gaming Chai...  ฿5,990 - ฿6,290  None
# 47    Tengu เก้าอี้เล่นเกม รุ่น Kusanagi Gaming Chair  ฿2,020 - ฿2,590  None
# 48  MIREN เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร นั...    ฿999 - ฿1,598  None
# 49  MIREN เก้าอี้ เก้าอี้สำนักงาน เก้าอี้บาร์ ใช้ใ...         ฿700฿454  None
# 50  MABUY เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่งสบา...    ฿899 - ฿1,589  None
# 51  พร้อมส่งจ้า👽เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gami...  ฿1,499 - ฿3,299  None
# 52  เก้าอี้ขาเหล็กคู่ 18 24 30 นิ้ว เก้าอี้บาร์ เก...      ฿295 - ฿395  None
# 53  มาแล้ว เก้าอี้มาเล เก้าอี้นั่งปรับนอนได้ เก้าอ...             ฿550  None
# 54  🔥ถูกที่สุด🔥เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่ง...    ฿320 - ฿1,599  None
# 55  Neolution E-Sport Twilight Gaming RGB Chair (G...     ฿5,990฿4,490  None
# 56  [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ ...    ฿12,900฿9,700  None
# 57  NUBWO CH-010 เก้าอี้เกมมิ่ง Gaming Chair (รับป...     ฿4,990฿2,690  None
# 58  🔥พร้อมส่ง🔥เก้าอี้แค้มปิ้ง เก้าอี้พับ เก้าอี้แค...  ฿1,099 - ฿1,150  None
# 59  [Best Seller] Bewell Ergonomic chair เก้าอี้ทำ...   ฿29,900฿19,900  None

# %% [markdown]
# ### checkpoint 8 ตั้ง product เป็น index

# %%
shopee_df = shopee_df.set_index('product')
shopee_df
# Out:
#                                                               price sales
# product
# เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series ...     ฿6,698฿4,699  None
# SIGNO E-Sport GC-205 BLACKER Gaming Chair เก้าอ...     ฿5,490฿4,790  None
# NUBWO CH-011 เก้าอี้เกมมิ่ง Gaming Chair - (Black)     ฿5,490฿4,490  None
# [New!] Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOST...    ฿15,900฿7,900  None
# YiFeng เก้าอี้ สไตล์โมเดิร์น  เก้าอี้พลาสติก ขา...      ฿173 - ฿513  None
# Hotmotor (ถูกที่สุด) เก้าอี้สำนักงาน ขาเหล็ก เก...  ฿1,045 - ฿1,699  None
# YYM เก้าอี้พับเก้าอี้ปรับนอน เตียงพับ เก้าอี้พั...      ฿199 - ฿999  None
# Hotmotor (ถูกที่สุด) เก้าอี้ทำงาน เก้าอี้ พนักพ...  ฿1,045 - ฿1,899  None
# เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร พนักพิงหลังสูง...    ฿999 - ฿1,599  None
# [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ D...    ฿12,900฿9,700  None
# เก้าอี้สแตนเลส เกรด201 เก้าอี้กลมขาคู่ เก้าอี้ก...      ฿157 - ฿195  None
# MMY  เก้าอี้ 49*45*81cm เก้าอี้สไตล์ ขาไม้สีบีช...      ฿289 - ฿549  None
# Neolution E-sport Gaming Chair รุ่น G808 (G7_10...     ฿1,990฿1,790  None
# เก้าอี้สำนักงาน เก้าอี้พักผ่อน เก้าอี้ผู้บริหาร...    ฿995 - ฿1,595  None
# [HOT DEAL] เก้าอี้ ADDE โครงเหล็ก เบาะโพลี สามา...      ฿379 - ฿399  None
# เก้าอี้ รุ่น ROBOT ปรับสูง-ต่ำ ปรับแขนขึ้น-ลง ป...      ฿859 - ฿899  None
# เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gaming Chair ปรับ...  ฿1,234 - ฿3,990  None
# 🔥UPick1 เก้าอี้สำนักงาน เก้าอี้เล่นคอม 46x55x10...     ฿1,699฿1,189  None
# WOWLife เก้าอี้พักผ่อน ปรับเอนนอนได้ นุ่มสบายมี...         ฿890฿520  None
# (เก้าอี้เกมมิ่ง) GAMING CHAIR SPEED SPGX1 SHADO...     ฿5,990฿1,990  None
# เก้าอี้พักผ่อน เตียงพับ เก้าอี้พับ ปรับเอนนอนได...      ฿689 - ฿949  None
# โฮมออฟฟิศ Office Chair เก้าอี้สำนักงาน เก้าอี้น...       ฿1,290฿479  None
# KUMALL เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน มีล...       ฿1,599฿539  None
# Tengu เก้าอี้เล่นเกม Muramasa Gaming Chair                   ฿2,490  None
# เก้าอี้ทรงรถแข่ง มีหมอนรองหลังและคอ เก้าอี้เล่น...  ฿1,259 - ฿1,799  None
# BIGWOODS เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่งส...    ฿799 - ฿1,479  None
# [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภาพ...     ฿6,990฿4,590  None
# เก้าอี้ผู้บริหาร เก้าอี้สำนักงาน ปรับระดับได้ เ...    ฿959 - ฿1,390  None
# Nubwo Gaming Chair NBCH-024 แถมฟรี!!! ลำโพงรุ่น...     ฿4,390฿2,990  None
# Furinbox เก้าอี้สำนักงาน รุ่น COOPER - (สีดำ)          ฿3,990฿1,590  None
# (เก้าอี้เกมมิ่ง) THUNDER X3 DC3 GAMING  CHAIR B...     ฿6,390฿6,190  None
# SIGNO E-Sport Gaming Chair BLACKER รุ่น GC-205 ...           ฿4,790  None
# เก้าอี้ เก้าอี้สำนักงาน Office Chair เก้าอี้ทำง...         ฿799฿465  None
# kalevell เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร ...    ฿999 - ฿1,588  None
# เก้าอี้ทำงาน เก้าอี้สำนักงาน เก้าอี้ เก้าอี้ออฟ...    ฿995 - ฿1,245  None
# เก้าอี้ใส่เม็ดโฟมแล้ว CARLINO: พร้อมใช้งาน  ขนา...       ฿1,000฿599  None
# Anda Seat เก้าอี้เล่นเกม รุ่น Kaiser Series Pre...          ฿15,900  None
# ใหม่ล่าสุด!! ส่งเร็ว🚚!! ถูกสุด🔥เก้าอี้ออฟฟิศ เก...      ฿497 - ฿849  None
# [🏃ราคาพิเศษ สู้โควิด😍] เก้าอี้พับ เก้าอี้สนาม เ...       ฿99 - ฿189  None
# GIOCOSO เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่งทำงา...         ฿990฿485  None
# 🔥ถูกที่สุด🔥วันเดียวเท่านั้น! เก้าอี้สำนักงาน ขา...      ฿199 - ฿585  None
# เก้าอี้ เก้าอี้ออฟฟิศ เก้าอี้ทำงาน  เก้าอี้สำนั...      ฿459 - ฿489  None
# THUNDER X3 DC3 GAMING  CHAIR BLACK By Speedcom               ฿6,190  None
# Baanmainicha เก้าอี้ปรับนอน เก้าอี้พักผ่อน เก้า...           ฿1,980  None
# เก้าอี้พลาสติกมีพนักพิง ราคาถูก เก้าอี้นั่งทานข...         ฿250฿109  None
# เก้าอี้ รุ่น B (Black) Office Chair โฮมออฟฟิศ เ...         ฿990฿499  None
# [คืน 500c. ทักแชทรับโค้ด] ONEX-GX3 Gaming Chair...  ฿5,990 - ฿6,290  None
# Tengu เก้าอี้เล่นเกม รุ่น Kusanagi Gaming Chair     ฿2,020 - ฿2,590  None
# MIREN เก้าอี้ทำงาน ใช้กับสำนักงาน ผู้บริหาร นั่...    ฿999 - ฿1,598  None
# MIREN เก้าอี้ เก้าอี้สำนักงาน เก้าอี้บาร์ ใช้ใน...         ฿700฿454  None
# MABUY เก้าอี้สำนักงาน เก้าอี้ผู้บริหาร นั่งสบาย...    ฿899 - ฿1,589  None
# พร้อมส่งจ้า👽เก้าอี้เล่นเกม เก้าอี้เกมมิ่ง Gamin...  ฿1,499 - ฿3,299  None
# เก้าอี้ขาเหล็กคู่ 18 24 30 นิ้ว เก้าอี้บาร์ เก้...      ฿295 - ฿395  None
# มาแล้ว เก้าอี้มาเล เก้าอี้นั่งปรับนอนได้ เก้าอี...             ฿550  None
# 🔥ถูกที่สุด🔥เก้าอี้ เก้าอี้สำนักงาน เก้าอี้นั่งท...    ฿320 - ฿1,599  None
# Neolution E-Sport Twilight Gaming RGB Chair (G7...     ฿5,990฿4,490  None
# [ส่งฟรี รับประกัน3ปี] เก้าอี้ทำงานเพื่อสุขภาพ D...    ฿12,900฿9,700  None
# NUBWO CH-010 เก้าอี้เกมมิ่ง Gaming Chair (รับปร...     ฿4,990฿2,690  None
# 🔥พร้อมส่ง🔥เก้าอี้แค้มปิ้ง เก้าอี้พับ เก้าอี้แคม...  ฿1,099 - ฿1,150  None
# [Best Seller] Bewell Ergonomic chair เก้าอี้ทำง...   ฿29,900฿19,900  None

# %% [markdown]
# ### checkpoint 9 รวมคำสั่งไว้ใน cell เดียวกัน

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import bs4
import time

def prepare_shopee(chromedriver_path):
    driver = webdriver.Chrome(executable_path=chromedriver_path)
    driver.get('https://shopee.co.th/')
    thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
    thai_button.click()
    close_popup = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
    close_popup.click()
    return driver

def prepare_data(driver,keyword):
    search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')
    search_bar.click()
    search_bar.send_keys(keyword)
    search_bar.send_keys(Keys.ENTER)
    driver.execute_script('document.body.style.zoom="10%"')
    return driver

def get_shopee_df(driver):
    time.sleep(2)
    html_string = driver.page_source
    soup = bs4.BeautifulSoup(html_string)
    all_listing = soup.find_all('div',{'data-sqe':'item'})

    name_list = []
    price_list = []
    sales_list = []
    for listing in all_listing:

        name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
        price = listing.find('div',{'class':'hpDKMN'}).text
        sales = listing.find('div',{'class':'r6HknA'}).text
        
        name_list.append(name)
        price_list.append(price)
        sales_list.append(sales)

    shopee_df = pd.DataFrame([name_list,price_list,sales_list]).transpose()
    return shopee_df

# %% [markdown]
# ### checkpoint 10 การใช้งานคำสั่งต่างๆ และบันทึกตารางเป็นไฟล์ excel

# %%
import pyautogui

keyword = pyautogui.prompt(text='ใส่ keyword ที่ต้องการค้นหา',title='shopee_scraper')
chromedriver_path = pyautogui.prompt(text='ใส่ที่อยู่ของไฟล์ chromedriver.exe',title='shopee_scraper')

driver = prepare_shopee(chromedriver_path)
driver = prepare_data(driver,keyword)

shopee_df = get_shopee_df(driver)

shopee_df.columns = ['product','price','sales']
shopee_df = shopee_df.set_index('product')
shopee_df.to_excel(keyword+' shopee.xlsx')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path)
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %% [markdown]
# ### checkpoint 11 การสร้าง main คำสั่งเรียกใช้ฟังก์ชัน

# %%
def main():
    keyword = pyautogui.prompt(text='ใส่ keyword ที่ต้องการค้นหา',title='shopee_scraper')
    chromedriver_path = pyautogui.prompt(text='ใส่ที่อยู่ของไฟล์ chromedriver.exe',title='shopee_scraper')
    
    
    driver = prepare_shopee(chromedriver_path)
    driver = prepare_data(driver,keyword)
    
    shopee_df = get_shopee_df(driver)

    shopee_df.columns = ['product','price','sales']
    shopee_df = shopee_df.set_index('product')
    shopee_df.to_excel(keyword+' shopee.xlsx')

# %%
main()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path)
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/3092564534.py:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %%
#!/usr/bin/env python
# coding: utf-8

# checkpoint 1 

#In[32]:

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def prepare_shopee(chromedriver_path):
    driver = webdriver.Chrome(executable_path=chromedriver_path)
    driver.get('https://shopee.co.th/')
    thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
    thai_button.click()
    close_popup = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
    close_popup.click()
    return driver

def prepare_data(driver,keyword):
    search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')
    search_bar.click()
    search_bar.send_keys('เก้าอี้ ergonomic')
    search_bar.send_keys(Keys.ENTER)
    driver.execute_script('document.body.style.zoom="10%"')
    return driver

def get_shopee_df(driver):
    time.sleep(2)
    html_string = driver.page_source
    soup = bs4.BeautifulSoup(html_string)
    all_listing = soup.find_all('div',{'data-sqe':'item'})

    name_list = []
    price_list = []
    sales_list = []
    for listing in all_listing:

        name = listing.find('div',{'class':'ie3A+n bM+7UW Cve6sh'}).text
        price = listing.find('div',{'class':'hpDKMN'}).text
        sales = listing.find('div',{'class':'r6HknA'}).text
        
        name_list.append(name)
        price_list.append(price)
        sales_list.append(sales)

    shopee_df = pd.DataFrame([name_list,price_list,sales_list]).transpose()
    return shopee_df

def main():
    keyword = pyautogui.prompt(text='ใส่ keyword ที่ต้องการค้นหา',title='shopee_scraper')
    chromedriver_path = pyautogui.prompt(text='ใส่ที่อยู่ของไฟล์ chromedriver.exe',title='shopee_scraper')
    
    
    driver = prepare_shopee(chromedriver_path)
    driver = prepare_data(driver,keyword)
    
    shopee_df = get_shopee_df(driver)

    shopee_df.columns = ['product','price','sales']
    shopee_df = shopee_df.set_index('product')
    shopee_df.to_excel(keyword+' shopee.xlsx')

if __name__ == "__main__":
    main()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/688729623.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path)
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/688729623.py:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   thai_button = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
# C:\Users\User\AppData\Local\Temp/ipykernel_10916/688729623.py:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %%
im
